# %% [markdown]
# <a href="https://colab.research.google.com/github/21Stonney/langchain-gemini-starter/blob/main/it_aiagtactdj_01_enus_04_asset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  Install required packages
# !pip install -qU langchain langchain-google-genai google-generativeai==0.8.5

# %%
#  Imports
import os
from google.colab import userdata
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain.chains import LLMChain

# %%
#  Set API Key
os.environ["GOOGLE_API_KEY"] = userdata.get("GEMINI_API_KEY")

# %%
#  Create Gemini LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    temperature=0.7,
    convert_system_message_to_human=True
)

# %%
#  Prompt to get user's name
name_prompt = PromptTemplate.from_template("My name is {name}. Please remember it and greet me.")

# %%
#  Prompt to ask if it remembers the name
followup_prompt = PromptTemplate.from_template("Do you remember my name?")

# %%
#  Create Chains
name_chain = LLMChain(llm=llm, prompt=name_prompt)
followup_chain = LLMChain(llm=llm, prompt=followup_prompt)
# Out:
# /tmp/ipython-input-1112660302.py:2: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   name_chain = LLMChain(llm=llm, prompt=name_prompt)

# %%
#  Run both chains
name = input("Enter your name: ")
greet = name_chain.invoke({"name": name})  # First prompt - gives name
print("\n  Greet:\n", greet["text"])

print("\n Asking if it remembers your name...")
response = followup_chain.invoke({})  # Second prompt - ask if it remembers

print("\n  Response:\n", response["text"])
